# %%
from plntxps import *

# %% [raw]
# make_blank_experiment_table("data/", "experiment table.csv")
# # then manually fill out the labels (or do something clever
# # but specific)

# %% [raw]
# make_blank_region_table("region table.csv")

# %% [raw]
# # add regions to region table manually
# # then call fill out function
# fill_out_region_table('region table.csv', "peaks", "params")

# %%
region_table = pd.read_csv('region table.csv', sep = '\t')
experiment_table = read_experiment_table('experiment table.csv')

# %% [raw]
# make_empty_fit_table(experiment_table, region_table, 'fit table.csv')

# %% [raw]
# make_empty_peak_tables(region_table, "peaks")
# # manually fill out peak tables

# %%
fit_table = pd.read_csv('fit table.csv', sep = '\t')
peak_tables = read_peak_tables(region_table)
satellites = get_satellites('al')

# %% [raw]
# make_params_files(region_table, peak_tables, satellites)

# %%
batch_fit = XpsBatchFit(
    experiment_table,
    region_table,
    fit_table,
    peak_tables)

# %%
batch_fit.check_guess('Pellet 3.8 14.0 450.0', 'Mo 3d', satellites)
# Out:
# /home/geci/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/lmfitxps/lineshapes.py:216: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   out = sc_convolve(padded_data, kernel, mode='valid', method="fft")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 batch_fit.check_guess('Pellet 3.8 14.0 450.0', 'Mo 3d', satellites)
#
# File ~/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/plntxps/fitting.py:270, in XpsBatchFit.check_guess(self, experiment, region, satellites)
#     267 plot_initial_guess(
#     268     fit_model, params_path, spectrum.eV, spectrum.counts, guess_shirley)
#     269 plt.show()
# --> 270 fit = do_fit(
#     271     spectrum.eV, spectrum.counts, fit_model, params_path, guess_shirley)
#     272 plot_fit_result(spectrum.eV, spectrum.counts, fit, satellites)
#     273 return fit
#
# File ~/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/plntxps/fitting.py:116, in do_fit(eV, counts, fit_model, params_path, guess_shirley)
#     114 if guess_shirley:
#     115     auto_shirley(params, counts)
# --> 116 result = fit_model.fit(counts, params,
#     117     x = eV, y = counts)
#     118 return result
#
# File ~/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/lmfit/model.py:1181, in Model.fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, calc_covar, max_nfev, coerce_farray, **kwargs)
#    1175     fit_kws = {}
#    1177 output = ModelResult(self, params, method=method, iter_cb=iter_cb,
#    1178                      scale_covar=scale_covar, fcn_kws=kwargs,
#    1179                      nan_policy=self.nan_policy, calc_covar=calc_covar,
#    1180                      max_nfev=max_nfev, **fit_kws)
# -> 1181 output.fit(data=data, weights=weights)
#    1182 output.components = self.components
#    1183 return output
#
# File ~/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/lmfit/model.py:1577, in ModelResult.fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1575 self.userkws.update(kwargs)
#    1576 self.init_fit = self.model.eval(params=self.init_params, **self.userkws)
# -> 1577 _ret = self.minimize(method=self.method, params=self.init_params)
#    1578 self.model.post_fit(_ret)
#    1579 _ret.params.create_uvars(covar=_ret.covar)
#
# File ~/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/lmfit/minimizer.py:2455, in Minimizer.minimize(self, method, params, **kws)
#    2452         if (key.lower().startswith(user_method) or
#    2453                 val.lower().startswith(user_method)):
#    2454             kwargs['method'] = val
# -> 2455 return function(**kwargs)
#
# File ~/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/lmfit/minimizer.py:1686, in Minimizer.leastsq(self, params, max_nfev, **kws)
#    1684 result.call_kws = lskws
#    1685 try:
# -> 1686     lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1687 except AbortFitException:
#    1688     pass
#
# File ~/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:439, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     437     if maxfev == 0:
#     438         maxfev = 200*(n + 1)
# --> 439     retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
#     440                              gtol, maxfev, epsfcn, factor, diag)
#     441 else:
#     442     if col_deriv:
#
# File ~/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/lmfit/minimizer.py:527, in Minimizer.__residual(self, fvars, apply_bounds_transformation)
#     524     self.result.success = False
#     525     raise AbortFitException(f"fit aborted: too many function evaluations {self.max_nfev}")
# --> 527 out = self.userfcn(params, *self.userargs, **self.userkws)
#     529 if callable(self.iter_cb):
#     530     abort = self.iter_cb(params, self.result.nfev, out,
#     531                          *self.userargs, **self.userkws)
#
# File ~/Desktop/main_venv/jupyter_venv/lib/python3.13/site-packages/lmfit/model.py:882, in Model._residual(self, params, data, weights, **kwargs)
#     877 if self.nan_policy == 'raise' and not np.all(np.isfinite(model)):
#     878     msg = ('The model function generated NaN values and the fit '
#     879            'aborted! Please check your model function and/or set '
#     880            'boundaries on parameters where applicable. In cases like '
#     881            'this, using "nan_policy=\'omit\'" will probably not work.')
# --> 882     raise ValueError(msg)
#     884 diff = data - model
#     886 if diff.dtype is complex:
#     887     # data/model are complex
#
# ValueError: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
