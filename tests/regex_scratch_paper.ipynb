# %%
# %run scratch_module.py

# %%
import numpy as np
import scipy as sp
import re
from enum import Enum
import matplotlib.pyplot as plt
from darkplot import *

# %%
TiO2_data = read_datafile('example data/Experiment 2025-1-24 SA 450.xy')
RhAl2O3_data = read_datafile('example data/2024-09-16 Rh on Al2O3 for Marlon 7-21-24 fit.xy')
SA_450_1_24 = read_datafile('example data/Experiment 2025-1-24 SA 450.xy')
SA_450_Au_1_24 = read_datafile('example data/Experiment 2025-1-24 Au SA 450.xy')

# %%
SA_450_Au_1_24.get_charge_referenced_peak_positions([1, 60], plot_result = True)
# Out:
# O 1s peak position: 530.1178 +- 0.0141
# Ti 2p peak position: 458.9028 +- 0.0209

# %%
SA_450_1_24.charge_reference_valence_band_spectra([62, 266], SA_450_Au_1_24)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 SA_450_1_24.charge_reference_valence_band_spectra([62, 266], SA_450_Au_1_24)
#
# File ~/Documents/repos/XPS_Analysis_Code/tests/scratch_module.py:359, in DataFile.charge_reference_valence_band_spectra(self, time_slice, reference_spectrum, s, reference_peaks, valence_band_name, save_figures)
#     354 included_valence_band_spectra = [x for x in self.spectra
#     355     if x.name == valence_band_name
#     356     and (slice_start <= x.time - self.start_time <= slice_end)]
#     357 total_valence_band_spectrum_count = [x for x in self.spectra
#     358     if x.name == valence_band_name]
# --> 359 excluded_valence_band_spectra_count = (total_valence_band_spectrum_count
#     360                                      - len(included_valence_band_spectra))
# ...

# %%
TiO2_data.list_spectra()

# %%
RhAl2O3_data.list_spectra()
