# %%
# %run scratch_module.py

# %%
import numpy as np
import scipy as sp
import re
from enum import Enum
import matplotlib.pyplot as plt
from darkplot import *

# %%
data = read_datafile('example data/Experiment 2025-1-24 SA 450.xy')
