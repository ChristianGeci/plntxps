# %%
# %run scratch_module.py

# %%
import numpy as np
import scipy as sp
import re
from enum import Enum
import matplotlib.pyplot as plt
from darkplot import *

# %%
TiO2_data = read_datafile('example data/Experiment 2025-1-24 SA 450.xy')
RhAl2O3_data = read_datafile('example data/2024-09-16 Rh on Al2O3 for Marlon 7-21-24 fit.xy')
SA_450_Au_1_24 = read_datafile('example data/Experiment 2025-1-24 Au SA 450.xy')

# %%
SA_450_Au_1_24.get_charge_referenced_peak_positions([1, 60])
# Out:
# O 1s peak position: 530.1178 +- 0.0141
# Ti 2p peak position: 458.9028 +- 0.0209

# %%
TiO2_data.list_spectra()
# Out:
# Index  Name          Time (min)
# 0      Ti 2p         529.27
#        Peak Location
#
# 1      O 1s          531.13
#        Peak Location
#
# 2      Ti 2p         532.65
#        Peak Location
#
# 3      O 1s          534.52
#        Peak Location
#
# 4      Ti 2p         536.02
#        Peak Location
#
# 5      O 1s          537.88
#        Peak Location
#
# 6      Ti 2p         539.40
#        Peak Location
#
# 7      O 1s          541.25
#        Peak Location
#
# 8      Ti 2p         542.77
#        Peak Location
#
# 9      O 1s          544.62
#        Peak Location
#
# 10     Ti 2p         546.13
#        Peak Location
#
# 11     O 1s          548.00
#        Peak Location
#
# 12     Ti 2p         549.52
#        Peak Location
#
# 13     O 1s          551.38
#        Peak Location
#
# 14     Ti 2p         552.90
#        Peak Location
#
# 15     O 1s          554.77
#        Peak Location
#
# 16     Ti 2p         556.28
#        Peak Location
#
# 17     O 1s          558.13
#        Peak Location
#
# 18     Ti 2p         559.65
#        Peak Location
#
# 19     O 1s          561.52
#        Peak Location
#
# 20     Ti 2p         563.02
#        Peak Location
#
# 21     O 1s          564.88
#        Peak Location
#
# 22     Ti 2p         566.40
#        Peak Location
#
# 23     O 1s          568.25
#        Peak Location
#
# 24     Ti 2p         569.77
#        Peak Location
#
# 25     O 1s          571.63
#        Peak Location
#
# 26     Ti 2p         573.15
#        Peak Location
#
# 27     O 1s          575.00
#        Peak Location
#
# 28     Ti 2p         576.52
#        Peak Location
#
# 29     O 1s          578.38
#        Peak Location
#
# 30     Ti 2p         579.90
#        Peak Location
#
# 31     O 1s          581.75
#        Peak Location
#
# 32     Ti 2p         583.27
#        Peak Location
#
# 33     O 1s          585.13
#        Peak Location
#
# 34     Ti 2p         586.65
#        Peak Location
#
# 35     O 1s          588.50
#        Peak Location
#
# 36     Ti 2p         590.02
#        Peak Location
#
# 37     O 1s          591.88
#        Peak Location
#
# 38     Ti 2p         593.38
#        Peak Location
#
# 39     O 1s          595.25
#        Peak Location
#
# 40     Ti 2p         596.77
#        Peak Location
#
# 41     O 1s          598.63
#        Peak Location
#
# 42     Ti 2p         600.15
#        Peak Location
#
# 43     O 1s          602.02
#        Peak Location
#
# 44     Ti 2p         603.53
#        Peak Location
#
# 45     O 1s          605.38
#        Peak Location
#
# 46     Ti 2p         606.90
#        Peak Location
#
# 47     O 1s          608.77
#        Peak Location
#
# 48     Ti 2p         610.53
#        Peak Location
#
# 49     O 1s          612.32
#        Peak Location
#
# 50     Valence Band  613.25
#
# 51     Valence Band  614.20
#
# 52     Valence Band  615.13
#
# 53     Valence Band  616.07
#
# 54     Valence Band  617.00
#
# 55     Valence Band  617.93
#
# 56     Valence Band  618.87
#
# 57     Valence Band  619.80
#
# 58     Valence Band  620.73
#
# 59     Valence Band  621.67
#
# 60     Ti 2p         623.43
#        Peak Location
#
# 61     O 1s          625.22
#        Peak Location
#
# 62     Valence Band  626.17
#
# 63     Valence Band  627.10
#
# 64     Valence Band  628.03
#
# 65     Valence Band  628.97
#
# 66     Valence Band  629.90
#
# 67     Valence Band  630.83
#
# 68     Valence Band  631.77
#
# 69     Valence Band  632.70
#
# 70     Valence Band  633.65
#
# 71     Valence Band  634.58
#
# 72     Ti 2p         636.33
#        Peak Location
#
# 73     O 1s          638.12
#        Peak Location
#
# 74     Valence Band  639.07
#
# 75     Valence Band  640.00
#
# 76     Valence Band  640.93
#
# 77     Valence Band  641.87
#
# 78     Valence Band  642.80
#
# 79     Valence Band  643.73
#
# 80     Valence Band  644.68
#
# 81     Valence Band  645.62
#
# 82     Valence Band  646.55
#
# 83     Valence Band  647.48
#
# 84     Ti 2p         649.25
#        Peak Location
#
# 85     O 1s          651.03
#        Peak Location
#
# 86     Valence Band  651.98
#
# 87     Valence Band  652.92
#
# 88     Valence Band  653.85
#
# 89     Valence Band  654.78
#
# 90     Valence Band  655.72
#
# 91     Valence Band  656.65
#
# 92     Valence Band  657.58
#
# 93     Valence Band  658.52
#
# 94     Valence Band  659.45
#
# 95     Valence Band  660.38
#
# 96     Ti 2p         662.15
#        Peak Location
#
# 97     O 1s          663.93
#        Peak Location
#
# 98     Valence Band  664.88
#
# 99     Valence Band  665.82
#
# 100    Valence Band  666.75
#
# 101    Valence Band  667.68
#
# 102    Valence Band  668.62
#
# 103    Valence Band  669.55
#
# 104    Valence Band  670.50
#
# 105    Valence Band  671.43
#
# 106    Valence Band  672.37
#
# 107    Valence Band  673.30
#
# 108    Ti 2p         675.05
#        Peak Location
#
# 109    O 1s          676.83
#        Peak Location
#
# 110    Valence Band  677.78
#
# 111    Valence Band  678.72
#
# 112    Valence Band  679.65
#
# 113    Valence Band  680.58
#
# 114    Valence Band  681.53
#
# 115    Valence Band  682.47
#
# 116    Valence Band  683.40
#
# 117    Valence Band  684.33
#
# 118    Valence Band  685.27
#
# 119    Valence Band  686.20
#
# 120    Ti 2p         687.97
#        Peak Location
#
# 121    O 1s          689.75
#        Peak Location
#
# 122    Valence Band  690.68
#
# 123    Valence Band  691.62
#
# 124    Valence Band  692.57
#
# 125    Valence Band  693.50
#
# 126    Valence Band  694.43
#
# 127    Valence Band  695.37
#
# 128    Valence Band  696.30
#
# 129    Valence Band  697.23
#
# 130    Valence Band  698.17
#
# 131    Valence Band  699.10
#
# 132    Ti 2p         700.85
#        Peak Location
#
# 133    O 1s          702.65
#        Peak Location
#
# 134    Valence Band  703.58
#
# 135    Valence Band  704.52
#
# 136    Valence Band  705.47
#
# 137    Valence Band  706.40
#
# 138    Valence Band  707.33
#
# 139    Valence Band  708.27
#
# 140    Valence Band  709.20
#
# 141    Valence Band  710.13
#
# 142    Valence Band  711.08
#
# 143    Valence Band  712.02
#
# 144    Ti 2p         713.77
#        Peak Location
#
# 145    O 1s          715.55
#        Peak Location
#
# 146    Valence Band  716.50
#
# 147    Valence Band  717.43
#
# 148    Valence Band  718.38
#
# 149    Valence Band  719.32
#
# 150    Valence Band  720.25
#
# 151    Valence Band  721.18
#
# 152    Valence Band  722.12
#
# 153    Valence Band  723.05
#
# 154    Valence Band  724.00
#
# 155    Valence Band  724.93
#
# 156    Ti 2p         726.68
#        Peak Location
#
# 157    O 1s          728.47
#        Peak Location
#
# 158    Valence Band  729.42
#
# 159    Valence Band  730.35
#
# 160    Valence Band  731.28
#
# 161    Valence Band  732.22
#
# 162    Valence Band  733.15
#
# 163    Valence Band  734.08
#
# 164    Valence Band  735.02
#
# 165    Valence Band  735.95
#
# 166    Valence Band  736.90
#
# 167    Valence Band  737.83
#
# 168    Ti 2p         739.58
#        Peak Location
#
# 169    O 1s          741.38
#        Peak Location
#
# 170    Valence Band  742.32
#
# 171    Valence Band  743.25
#
# 172    Valence Band  744.20
#
# 173    Valence Band  745.13
#
# 174    Valence Band  746.07
#
# 175    Valence Band  747.00
#
# 176    Valence Band  747.93
#
# 177    Valence Band  748.87
#
# 178    Valence Band  749.82
#
# 179    Valence Band  750.75
#
# 180    Ti 2p         752.50
#        Peak Location
#
# 181    O 1s          754.30
#        Peak Location
#
# 182    Valence Band  755.23
#
# 183    Valence Band  756.17
#
# 184    Valence Band  757.12
#
# 185    Valence Band  758.05
#
# 186    Valence Band  758.98
#
# 187    Valence Band  759.92
#
# 188    Valence Band  760.85
#
# 189    Valence Band  761.78
#
# 190    Valence Band  762.73
#
# 191    Valence Band  763.67
#
# 192    Ti 2p         765.42
#        Peak Location
#
# 193    O 1s          767.20
#        Peak Location
#
# 194    Valence Band  768.15
#
# 195    Valence Band  769.08
#
# 196    Valence Band  770.02
#
# 197    Valence Band  770.95
#
# 198    Valence Band  771.88
#
# 199    Valence Band  772.82
#
# 200    Valence Band  773.75
#
# 201    Valence Band  774.70
#
# 202    Valence Band  775.63
#
# 203    Valence Band  776.57
#
# 204    Ti 2p         778.32
#        Peak Location
#
# 205    O 1s          780.10
#        Peak Location
#
# 206    Valence Band  781.05
#
# 207    Valence Band  781.98
#
# 208    Valence Band  782.92
#
# 209    Valence Band  783.85
#
# 210    Valence Band  784.80
#
# 211    Valence Band  785.73
#
# 212    Valence Band  786.67
#
# 213    Valence Band  787.60
#
# 214    Valence Band  788.53
#
# 215    Valence Band  789.47
#
# 216    Ti 2p         791.22
#        Peak Location
#
# 217    O 1s          793.00
#        Peak Location
#
# 218    Valence Band  793.95
#
# 219    Valence Band  794.88
#
# 220    Valence Band  795.82
#
# 221    Valence Band  796.75
#
# 222    Valence Band  797.68
#
# 223    Valence Band  798.62
#
# 224    Valence Band  799.55
#
# 225    Valence Band  800.48
#
# 226    Valence Band  801.42
#
# 227    Valence Band  802.35
#
# 228    Ti 2p         804.12
#        Peak Location
#
# 229    O 1s          805.90
#        Peak Location
#
# 230    Ti 2p         807.65
#        Peak Location
#
# 231    O 1s          809.43
#        Peak Location

# %%
charge_curve = TiO2_data.get_charge_curve("Ti 2p")
charge_curve.scatter()
charge_curve.slice(50, 200).scatter()

# %%
RhAl2O3_data.list_spectra()
# Out:
# Index  Name                               Time (min)
# 0      overall 8B                         882.12
#
# 1      overall 8B, shifted work function  891.98
#
# 2      Rh 3d 10 eV                        917.13
#
# 3      overall 8B post-gold evaporation   1052.43
#
# 4      Rh 3d 10 eV                        1065.98
#
# 5      Au 4d 10 eV                        1091.77
#        Peak Fit
#
# 6      Au 4d 10 eV flood gun off          1102.25
#        Peak Location
#
# 7      Au 4d 10 eV                        1105.90
#        Peak Location
#
# 8      Au 4d 10 eV                        1110.47
#
# 9      Au 4d 10 eV                        1113.70
#        Peak Location
#
# 10     Au 4d 10 eV                        1117.23
#        Peak Location
#
# 11     Au 4f 10 eV                        1119.18
#        Peak Location
#
# 12     Au 4f 10 eV                        1122.27
#        Peak Location
#
# 13     Au 4f 10 eV                        1124.52
#        Peak Location
#
# 14     Rh 3d 10 eV                        1131.07
#
# 15     Au 4f 10 eV                        1156.65
#
# 16     Rh 3d 10 eV                        1175.72
#
# 17     Au 4d 10 eV                        1201.83
#
# 18     Au 4f 10 eV                        841.02
#        Peak Location
#
# 19     Rh 3d 10 eV                        860.08
#        Multi Peak Fit
#        Peak Location
#        Multi Peak Fit
#
# 20     Au 4d 10 eV                        886.20
#        Multi Peak Fit
#        Peak Location
